# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/Laxminarayen/Inceptez-batch-25-Classwork/refs/heads/main/Python-Class11-Pandas-Intermediate/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/shans28/pandas-viz-stats-practice/refs/heads/main/data/US_Crime_Rates_1960_2014.csv")

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
df.dtypes
# Out:
# Year                  int32
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
df['Year']=pd.to_datetime(df['Year'], format="%Y")

# %%
df.dtypes
# Out:
# Year                  datetime64[ns]
# Population                     int64
# Violent                        int64
# Property                       int64
# Murder                         int64
# Forcible_Rape                  int64
# Robbery                        int64
# Aggravated_assault             int64
# Burglary                       int64
# Larceny_Theft                  int64
# Vehicle_Theft                  int64
# year_grouped                  object
# dtype: object

# %%
df
# Out:
#          Year  Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0  1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1  1961-01-01   182992000   289390   3198600    8740          17220   106670
# 2  1962-01-01   185771000   301510   3450700    8530          17550   110860
# 3  1963-01-01   188483000   316970   3792500    8640          17650   116470
# 4  1964-01-01   191141000   364220   4200400    9360          21420   130390
# 5  1965-01-01   193526000   387390   4352000    9960          23410   138690
# 6  1966-01-01   195576000   430180   4793300   11040          25820   157990
# 7  1967-01-01   197457000   499930   5403500   12240          27620   202910
# 8  1968-01-01   199399000   595010   6125200   13800          31670   262840
# 9  1969-01-01   201385000   661870   6749000   14760          37170   298850
# 10 1970-01-01   203235298   738820   7359200   16000          37990   349860
# ...

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
df.set_index('Year')
# Out:
#             Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 1964-01-01   191141000   364220   4200400    9360          21420   130390
# 1965-01-01   193526000   387390   4352000    9960          23410   138690
# 1966-01-01   195576000   430180   4793300   11040          25820   157990
# 1967-01-01   197457000   499930   5403500   12240          27620   202910
# 1968-01-01   199399000   595010   6125200   13800          31670   262840
# 1969-01-01   201385000   661870   6749000   14760          37170   298850
# 1970-01-01   203235298   738820   7359200   16000          37990   349860
# 1971-01-01   206212000   816500   7771700   17780          42260   387700
# ...

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
df.drop('Total', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3797983840.py in <cell line: 0>()
# ----> 1 df.drop('Total', axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
df["decade"] = (df["Year"].dt.year // 10) * 10

# %%
df.head()
#df.groupby("decade").sum()
# Out:
#         Year  Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 2 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 3 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 4 1964-01-01   191141000   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800
#
#                     year_grouped  decade
# 0  (1960-01-01 00:00:00, [Year])    1960
# 1  (1961-01-01 00:00:00, [Year])    1960
# ...

# %%
crime_cols = df.columns.drop(["Year", "Population", "decade"])

# %%
df_decade=df.groupby('decade')[crime_cols].sum()

# %%
df_decade
# Out:
#          Violent   Property  Murder  Forcible_Rape  Robbery  \
# decade
# 1960     4134930   45160900  106180         236720  1633510
# 1970     9607930   91383800  192230         554570  4159020
# 1980    14074328  117048900  206439         865639  5383109
# 1990    17527048  119053499  211664         998827  5748930
# 2000    13968056  100944369  163068         922499  4230366
# 2010     6072017   44095950   72867         421059  1749809
#
#         Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# decade
# 1960               2158520  13321100       26547700        5292100
# 1970               4702120  28486000       53157800        9739900
# 1980               7619130  33073494       72040253       11935411
# 1990              10568963  26750015       77679366       14624418
# 2000               8652124  21565176       67970291       11412834
# 2010               3764142  10125170       30401698        3569080
#
# ...

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
most_dangerous_decade = df_decade["Violent"].idxmax()

# %%
most_dangerous_decade
# Out:
# np.int32(1990)

# %%
#df_decade["Total_Crimes"] = df_decade.sum(axis=1)
df_decade["Total_Crimes"]=df_decade.drop(columns=["year_grouped"], errors="ignore").sum(axis=1)

# %%
df_decade
# Out:
#          Violent   Property  Murder  Forcible_Rape  Robbery  \
# decade
# 1960     4134930   45160900  106180         236720  1633510
# 1970     9607930   91383800  192230         554570  4159020
# 1980    14074328  117048900  206439         865639  5383109
# 1990    17527048  119053499  211664         998827  5748930
# 2000    13968056  100944369  163068         922499  4230366
# 2010     6072017   44095950   72867         421059  1749809
#
#         Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  \
# decade
# 1960               2158520  13321100       26547700        5292100
# 1970               4702120  28486000       53157800        9739900
# 1980               7619130  33073494       72040253       11935411
# 1990              10568963  26750015       77679366       14624418
# 2000               8652124  21565176       67970291       11412834
# 2010               3764142  10125170       30401698        3569080
#
# ...

# %%
most_dangerous_total = df_decade["Total_Crimes"].idxmax()

# %%
most_dangerous_total
# Out:
# np.int32(1990)
