# %% [markdown]
# ## One way ANOVA test Exercise

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
#stats.f_oneway?


# Reproducible randomn
np.random.seed(11)

# Number of people in each group
n_per_group = 35

# Group labels and their true means
groups = ['A','B','C','D']
true_means = [72, 80, 74, 76]
within_sd  = 8

# Build a DataFrame with generated data
data_frames = []
for g, mu in zip(groups, true_means):
    vals = np.random.normal(loc=mu, scale=within_sd, size=n_per_group)
    data_frames.append(pd.DataFrame({'group': g, 'score': vals}))

df = pd.concat(data_frames, ignore_index=True)
df.head()
# Out:
#   group      score
# 0     A  85.995638
# 1     A  69.711416
# 2     A  68.123479
# 3     A  50.773452
# 4     A  71.933723

# %% [markdown]
# ## Ho = Are all group means equal?
#
# ## Ha = Atleast one group mean is different

# %%
alpha = 0.05

samples = [df.loc[df.group == g,'score'].values for g in groups]
F, p = stats.f_oneway(*samples) #* argument unpacking proerations

# %%
samples
# Out:
# [array([85.99563793, 69.71141603, 68.12347894, 50.77345153, 71.93372297,
#         69.44294909, 67.7069651 , 74.52322135, 75.36840573, 63.47517616,
#         64.91008264, 68.19413206, 77.51745848, 76.48953741, 61.55561192,
#         63.04419791, 77.89469913, 84.59707258, 71.75139929, 66.53242698,
#         80.76503759, 69.5233869 , 77.8060178 , 84.39257307, 77.04063858,
#         72.5879459 , 77.85817083, 66.85939686, 70.5752546 , 67.40836352,
#         70.36499747, 68.1080392 , 70.51379741, 68.95570867, 72.71182108]),
#  array([80.50937329, 82.37077686, 91.22216896, 67.62509946, 90.36494868,
#         78.10199643, 70.14123035, 78.62064186, 80.734707  , 88.54046766,
#         71.50692441, 81.73878566, 80.94255603, 66.52711286, 70.51395788,
#         84.80081605, 85.56453804, 88.70168688, 84.27057373, 83.1616961 ,
#         80.98294023, 89.67281314, 73.25547119, 78.86485135, 83.0828331 ,
#         67.38004553, 90.48754912, 73.65707994, 79.4260047 , 97.25339541,
#         73.36450198, 75.76502378, 92.49362955, 71.3584494 , 76.54353905]),
#  array([78.1286723 , 77.64314288, 78.74948962, 76.96405067, 84.76302457,
#         82.12753717, 78.76222763, 68.53758707, 68.29152056, 58.73368367,
#         79.49849879, 59.41592333, 81.0329104 , 88.77091898, 65.50676477,
#         68.52412265, 70.19028416, 80.64248344, 67.09317987, 72.95566826,
#         69.81529894, 71.98978461, 84.33019783, 66.28636117, 74.57407819,
#         76.17285037, 80.86933739, 63.88741057, 82.91896228, 77.47821589,
#         80.99418213, 74.5732168 , 60.88758699, 68.82157895, 80.54215653]),
#  array([76.29435803, 75.61037966, 90.33224877, 93.61485051, 75.70346476,
#         91.46324343, 60.05142775, 59.60754192, 82.93644167, 73.90431141,
#         80.63176886, 80.13241908, 75.28477088, 81.45703768, 77.20577607,
#         63.74285982, 77.75094862, 77.48530604, 90.66221229, 66.96884479,
#         76.13597505, 72.6045694 , 74.93672081, 89.27363694, 79.02912547,
#         72.2834715 , 77.23072996, 82.12928496, 68.04777845, 73.88526137,
#         88.33767376, 82.84921637, 75.64157906, 72.18008617, 74.7674758 ])]

# %%
if p < alpha:
    print('Reject Ho') #not all group means are equal.
else:
    print('Fail to reject Ho') #NO enough evidence to say the groups are different.
# Out:
# Reject Ho
